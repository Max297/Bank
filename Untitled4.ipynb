# %% [markdown]
# <a href="https://colab.research.google.com/github/Max297/Bank/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import tensorflow.keras as keras
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from google.colab import drive
from sklearn.model_selection import train_test_split
from keras import backend as K
from keras.models import Sequential
from keras.layers import Activation
from keras.layers.core import Dense
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data=pd.read_csv('/content/drive/My Drive/Last_Hope.csv')
pd.set_option('display.max_columns', 20)
pd.set_option('display.max_rows', 30)

# %%
data
# Out:
#     Улица почтового отделения Расстояние до ближайшего почтового отделения  \
# 0                          А1                                          0.3
# 1                          А2                                          0.3
# 2                          А3                                          0.4
# 3                          А4                                          0.4
# 4                          А5                                          0.3
# ..                        ...                                          ...
# 179                 Кирова 28                                        1.09
# 180               Русская 65а                                        1.07
# 181       Адмирала Горшкова 3                                        1.78
# 182          ул. Кутузова, 3А                                        1.35
# 183      ул. Елиссейская, 20                                         2.12
#
#      Тип района  Тип здания  Проходимость  Категория отделения
# ...

# %%
data = data.sample(frac=1).reset_index(drop=True)

# %%
data=data.dropna()

# %%
feture_names=['Расстояние до ближайшего почтового отделения','Тип района','Тип здания','Проходимость']
target=data["Категория отделения"].values
features= data[feture_names].values

x_train,x_test,y_train,y_test=train_test_split(features,target,test_size=0.2)
y_test
# Out:
# array([1, 1, 3, 0, 3, 1, 0, 1, 1, 1, 1, 2, 2, 3, 2, 1, 0, 1, 3, 1, 1, 0,
#        3, 2, 3, 1, 3, 1, 0, 3, 3, 3, 1, 2, 1, 2, 2])

# %%
x_train=np.asarray(x_train).astype(np.float32)
y_train=np.asarray( y_train).astype(np.float32)
x_test=np.asarray(x_test).astype(np.float32)
y_test=np.asarray( y_test).astype(np.float32)

# %%
from keras.utils import normalize
x_train=normalize(x_train,axis=1)
x_test=normalize(x_test,axis=1)
x_test
# Out:
# array([[0.9808438 , 0.17619948, 0.05873316, 0.05873316],
#        [0.7013375 , 0.2910114 , 0.2910114 , 0.5820228 ],
#        [0.09008563, 0.9008562 , 0.3002854 , 0.3002854 ],
#        [0.07992189, 0.7992189 , 0.2664063 , 0.5328126 ],
#        [0.14285715, 0.5714286 , 0.5714286 , 0.5714286 ],
#        [0.7262763 , 0.39687225, 0.39687225, 0.39687225],
#        [0.11973687, 0.29934216, 0.29934216, 0.8980265 ],
#        [0.45703566, 0.5135232 , 0.5135232 , 0.5135232 ],
#        [0.4127535 , 0.37184998, 0.37184998, 0.74369997],
#        [0.7744037 , 0.36528477, 0.36528477, 0.36528477],
#        [0.7047511 , 0.48828018, 0.16276006, 0.48828018],
#        [0.23386486, 0.77954954, 0.25984985, 0.5196997 ],
#        [0.46108398, 0.5123155 , 0.5123155 , 0.5123155 ],
#        [0.1490712 , 0.2981424 , 0.2981424 , 0.8944272 ],
#        [0.25145945, 0.5587988 , 0.5587988 , 0.5587988 ],
#        [0.27477404, 0.39253435, 0.39253435, 0.7850687 ],
# ...

# %%
num=x_train.shape[1]
num
model = Sequential([
    Dense(5, input_shape=(num,), activation='relu'),
    Dense(5, activation='relu'),
    Dense(4, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, batch_size=29, epochs=5, shuffle=True, verbose=2)
# Out:
# Epoch 1/5
# 6/6 - 0s - loss: 1.3878 - accuracy: 0.2109
# Epoch 2/5
# 6/6 - 0s - loss: 1.3875 - accuracy: 0.2313
# Epoch 3/5
# 6/6 - 0s - loss: 1.3874 - accuracy: 0.2313
# Epoch 4/5
# 6/6 - 0s - loss: 1.3872 - accuracy: 0.2313
# Epoch 5/5
# 6/6 - 0s - loss: 1.3871 - accuracy: 0.2313

# %%
for i in range (0,100):
  model.fit(x_train, y_train, batch_size=29, epochs=5, shuffle=True, verbose=2)
# Out:
# Epoch 1/5
# 6/6 - 0s - loss: 1.3580 - accuracy: 0.2789
# Epoch 2/5
# 6/6 - 0s - loss: 1.3547 - accuracy: 0.2789
# Epoch 3/5
# 6/6 - 0s - loss: 1.3525 - accuracy: 0.2789
# Epoch 4/5
# 6/6 - 0s - loss: 1.3502 - accuracy: 0.2789
# Epoch 5/5
# 6/6 - 0s - loss: 1.3477 - accuracy: 0.2789
# Epoch 1/5
# 6/6 - 0s - loss: 1.3452 - accuracy: 0.2789
# Epoch 2/5
# 6/6 - 0s - loss: 1.3430 - accuracy: 0.2789
# Epoch 3/5
# 6/6 - 0s - loss: 1.3406 - accuracy: 0.2789
# Epoch 4/5
# 6/6 - 0s - loss: 1.3382 - accuracy: 0.2789
# Epoch 5/5
# 6/6 - 0s - loss: 1.3356 - accuracy: 0.2789
# Epoch 1/5
# 6/6 - 0s - loss: 1.3325 - accuracy: 0.2789
# Epoch 2/5
# 6/6 - 0s - loss: 1.3292 - accuracy: 0.2789
# Epoch 3/5
# 6/6 - 0s - loss: 1.3253 - accuracy: 0.2789
# Epoch 4/5
# 6/6 - 0s - loss: 1.3206 - accuracy: 0.2789
# Epoch 5/5
# 6/6 - 0s - loss: 1.3147 - accuracy: 0.2789
# Epoch 1/5
# 6/6 - 0s - loss: 1.3090 - accuracy: 0.2857
# Epoch 2/5
# 6/6 - 0s - loss: 1.3027 - accuracy: 0.2857
# Epoch 3/5
# ...

# %%
val_loss, val_acc = model.evaluate(x_test, y_test)
print(val_loss)
print(val_acc)
predictions = model.predict(x_test)
# Out:
# 2/2 [==============================] - 0s 2ms/step - loss: 0.6161 - accuracy: 0.7027
# 0.6160961389541626
# 0.7027027010917664

# %%
x_test
# Out:
# array([[0.9808438 , 0.17619948, 0.05873316, 0.05873316],
#        [0.7013375 , 0.2910114 , 0.2910114 , 0.5820228 ],
#        [0.09008563, 0.9008562 , 0.3002854 , 0.3002854 ],
#        [0.07992189, 0.7992189 , 0.2664063 , 0.5328126 ],
#        [0.14285715, 0.5714286 , 0.5714286 , 0.5714286 ],
#        [0.7262763 , 0.39687225, 0.39687225, 0.39687225],
#        [0.11973687, 0.29934216, 0.29934216, 0.8980265 ],
#        [0.45703566, 0.5135232 , 0.5135232 , 0.5135232 ],
#        [0.4127535 , 0.37184998, 0.37184998, 0.74369997],
#        [0.7744037 , 0.36528477, 0.36528477, 0.36528477],
#        [0.7047511 , 0.48828018, 0.16276006, 0.48828018],
#        [0.23386486, 0.77954954, 0.25984985, 0.5196997 ],
#        [0.46108398, 0.5123155 , 0.5123155 , 0.5123155 ],
#        [0.1490712 , 0.2981424 , 0.2981424 , 0.8944272 ],
#        [0.25145945, 0.5587988 , 0.5587988 , 0.5587988 ],
#        [0.27477404, 0.39253435, 0.39253435, 0.7850687 ],
# ...

# %%
print(y_test)
res=model.predict(x_test)
res
# Out:
# [1. 1. 3. 0. 3. 1. 0. 1. 1. 1. 1. 2. 2. 3. 2. 1. 0. 1. 3. 1. 1. 0. 3. 2.
#  3. 1. 3. 1. 0. 3. 3. 3. 1. 2. 1. 2. 2.]
# array([[1.77821576e-07, 8.77544522e-01, 1.22442521e-01, 1.27832127e-05],
#        [1.54721181e-06, 8.47087860e-01, 1.52846694e-01, 6.39219070e-05],
#        [5.34886777e-01, 4.51102480e-03, 5.53836450e-02, 4.05218571e-01],
#        [7.10362196e-01, 5.19539346e-04, 8.76973569e-03, 2.80348599e-01],
#        [4.27034408e-01, 8.67460668e-03, 1.18903272e-01, 4.45387691e-01],
#        [5.51351604e-07, 8.63190234e-01, 1.36779577e-01, 2.96101443e-05],
#        [6.63297176e-01, 1.06130575e-03, 1.48238363e-02, 3.20817620e-01],
#        [2.48063188e-05, 6.79041147e-01, 3.20341259e-01, 5.92891534e-04],
#        [3.64115200e-04, 4.69898522e-01, 5.24951816e-01, 4.78545995e-03],
#        [3.92882498e-07, 8.67634773e-01, 1.32341683e-01, 2.30261030e-05],
#        [1.37211885e-06, 8.49147737e-01, 1.50792420e-01, 5.84327390e-05],
# ...

# %%
def get_class( datta):
  feture_names=['Расстояние до ближайшего почтового отделения','Тип района','Тип здания','Проходимость']

  d = {'Категория отделения': []}
  df = pd.DataFrame(data=d)

  features= datta[feture_names].values
  x=np.asarray(features).astype(np.float32)
  x=normalize(x,axis=1)

  results=model.predict(x)

  for i in range (0,len(datta.index)):
    if results[i][0]>results[i][1] and results[i][0]>results[i][2] and results[i][0]>results[i][3] :
                df.loc[i]=0
    if results[i][1]>results[i][0] and results[i][1]>results[i][2] and results[i][1]>results[i][3] :
                df.loc[i]=1
    if results[i][2]>results[i][1] and results[i][2]>results[i][0] and results[i][2]>results[i][3] :
                df.loc[i]=2    
    if results[i][3]>results[i][1] and results[i][3]>results[i][2] and results[i][3]>results[i][0] :
                df.loc[i]=3    
  datta['Категория отделения']=df['Категория отделения']  

  return datta

# %%
m=pd.read_csv('/content/drive/My Drive/Last_Hope.csv')
l=m.drop('Категория отделения',axis=1)
i.drop('Категория отделения',axis=1)
j=get_class(l)
j
# Out:
#     Улица почтового отделения Расстояние до ближайшего почтового отделения  \
# 0                          А1                                          0.3
# 1                          А2                                          0.3
# 2                          А3                                          0.4
# 3                          А4                                          0.4
# 4                          А5                                          0.3
# ..                        ...                                          ...
# 179                 Кирова 28                                        1.09
# 180               Русская 65а                                        1.07
# 181       Адмирала Горшкова 3                                        1.78
# 182          ул. Кутузова, 3А                                        1.35
# 183      ул. Елиссейская, 20                                         2.12
#
#      Тип района  Тип здания  Проходимость  Категория отделения
# ...

# %%
model.save('/content/drive/My Drive/Models/')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/My Drive/Models/assets

# %%
new_model = keras.models.load_model('/content/drive/My Drive/Models/')
new_model.predict(l)

# %%
new_model.predict(x_test)
# Out:
# array([[1.77821576e-07, 8.77544522e-01, 1.22442521e-01, 1.27832127e-05],
#        [1.54721181e-06, 8.47087860e-01, 1.52846694e-01, 6.39219070e-05],
#        [5.34886777e-01, 4.51102480e-03, 5.53836450e-02, 4.05218571e-01],
#        [7.10362196e-01, 5.19539346e-04, 8.76973569e-03, 2.80348599e-01],
#        [4.27034408e-01, 8.67460668e-03, 1.18903272e-01, 4.45387691e-01],
#        [5.51351604e-07, 8.63190234e-01, 1.36779577e-01, 2.96101443e-05],
#        [6.63297176e-01, 1.06130575e-03, 1.48238363e-02, 3.20817620e-01],
#        [2.48063188e-05, 6.79041147e-01, 3.20341259e-01, 5.92891534e-04],
#        [3.64115200e-04, 4.69898522e-01, 5.24951816e-01, 4.78545995e-03],
#        [3.92882498e-07, 8.67634773e-01, 1.32341683e-01, 2.30261030e-05],
#        [1.37211885e-06, 8.49147737e-01, 1.50792420e-01, 5.84327390e-05],
#        [3.05549670e-02, 1.10859290e-01, 7.31443882e-01, 1.27141833e-01],
#        [2.23256939e-05, 6.88188314e-01, 3.11244786e-01, 5.44546871e-04],
# ...
